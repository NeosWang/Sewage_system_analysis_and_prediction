# %%
import pandas as pd
from tqdm import tqdm
from datetime import datetime, timedelta
import numpy as np

import matplotlib.pyplot as plt

import sys
sys.path.append("../")
import asset.MyPlot as mp
import asset.DataSupply as ds

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### load rainfall, sewage area,  mark all dry day

# %%
df_rain_historical, dct_areas = ds.GetRainfallByPumps(["Haarsteeg"])
location = dct_areas["haarsteeg"][0]
target_col = f"{location}_dry"
df_rain_historical = ds.MarkDryWeather(df_rain_historical, location)
df_rain_historical.head()
# Out:
# 100%|██████████| 22/22 [00:10<00:00,  2.07it/s]
#                      De Hoeven(Haarsteeg)  Haarsteeg  Heusdenseweg(Haarsteeg)  \
# end
# 2018-01-01 00:00:00                0.0000     0.0000                   0.0000
# 2018-01-01 01:00:00                0.0124     0.0000                   0.0000
# 2018-01-01 02:00:00                0.0789     0.0636                   0.0820
# 2018-01-01 03:00:00                0.0186     0.0172                   0.0205
# 2018-01-01 04:00:00                0.0036     0.0215                   0.0176
#
#                      Haarsteeg_dry
# end
# 2018-01-01 00:00:00          False
# 2018-01-01 01:00:00          False
# 2018-01-01 02:00:00          False
# 2018-01-01 03:00:00          False
# 2018-01-01 04:00:00          False

# %% [markdown]
# #### load and inner-join level and flow data

# %%
df_Bokhoven_level_old = ds.GetData("Haarsteeg", True, False)
df_Bokhoven_flow_old = ds.GetData("Haarsteeg", False, False)
# Out:
# 100%|██████████| 100/100 [00:16<00:00,  6.06it/s]
# 100%|██████████| 100/100 [00:16<00:00,  5.94it/s]

# %%
df_join = df_Bokhoven_level_old.join(df_Bokhoven_flow_old, how="inner")
df_join.head(3)
# Out:
#                      level_quality  level_value  flow_quality  flow_value
# end
# 2018-01-01 00:01:00            100         -0.2           100   60.846667
# 2018-01-01 00:02:00            100         -0.2           100   61.205000
# 2018-01-01 00:03:00            100         -0.2           100   61.015000

# %% [markdown]
# #### smoothing level data, from stepped to continous

# %%
df_join = ds.WaterLevelSmoothing(df_join)
# Out:
# 863820it [01:05, 13255.54it/s]

# %%
mp.PlotMulti(
    df_join[["level_value", "level_value_s", "flow_value"]][4000:5000], figsize=(16, 4)
)

# %% [markdown]
# #### mark level-flow data if dry-day

# %%
df_join["end_hour"] = df_join.index.ceil("h")
df_join["dry"] = False
for idx, row in tqdm(df_join.iterrows()):
    if df_rain_historical.at[row["end_hour"], target_col]:
        df_join.at[idx, "dry"] = True
# Out:
# 863820it [01:36, 8959.22it/s]

# %%
df_dry = df_join[
    (df_join["dry"])
    & (df_join["level_quality"] == 100)
    & (df_join["flow_quality"] == 100)
].copy()

df_dry["adj_level_diff_s"] = df_dry["level_diff_s"]
df_dry.loc[(df_dry["adj_level_diff_s"] < 0), "adj_level_diff_s"] = np.nan

df_dry["adj_level_diff_s"] = (
    df_dry["adj_level_diff_s"].ffill() + df_dry["adj_level_diff_s"].bfill()
) / 2
df_dry["adj_level_diff_s"] = df_dry["adj_level_diff_s"].fillna(0)
df_dry.head(3)
# Out:
#                      level_quality  level_value  flow_quality  flow_value  \
# end
# 2018-01-06 17:01:00            100         -2.5           100    0.248333
# 2018-01-06 17:02:00            100         -2.3           100    0.076667
# 2018-01-06 17:03:00            100         -2.1           100    0.076667
#
#                      level_diff  level_value_s  level_diff_s  \
# end
# 2018-01-06 17:01:00         0.3           -2.5           0.3
# 2018-01-06 17:02:00         0.2           -2.3           0.2
# 2018-01-06 17:03:00         0.2           -2.1           0.2
#
#                                end_hour   dry  adj_level_diff_s
# end
# 2018-01-06 17:01:00 2018-01-06 18:00:00  True               0.3
# 2018-01-06 17:02:00 2018-01-06 18:00:00  True               0.2
# 2018-01-06 17:03:00 2018-01-06 18:00:00  True               0.2

# %% [markdown]
# #### estimate the how much volume (m3) water could increase 1 meter water level

# %%
def InitDict():
    return {
        "up1": None,
        "up2": 0,
        "level_up": 0,
        "out": [],
        "start_level": 0,
        "end_level": 0,
    }


td = timedelta(minutes=1)
t0 = datetime(1900, 1, 1)
lst_m3_per_m = []
dct = InitDict()
for idx, row in tqdm(df_dry.iterrows()):
    if idx - t0 > td:  # if time is continuous
        dct = InitDict()
    else:
        if row["level_diff_s"] < 0 and dct["up1"] != 0:  # down after up
            dct["out"].append(row["flow_value"])
        if len(dct["out"]) == 0:  # no pump-out be recorded
            if row["level_diff_s"] > 0:
                if dct["up1"] is None:
                    dct["start_level"] = row["level_value_s"]
                dct["up1"] = row["level_diff_s"]

        else:
            if row["level_diff_s"] > 0:
                dct["up2"] = row["level_diff_s"]
                sss = np.sum(dct["out"]) / (
                    dct["level_up"] - dct["end_level"] + dct["start_level"]
                )
                lst_m3_per_m.append(sss)  #  m3/m water-level
                dct = InitDict()
    t0 = idx
    dct["end_level"] = row["level_value_s"]
    dct["level_up"] += row["adj_level_diff_s"]

avg_m3_per_m = np.average(lst_m3_per_m)
print(f"every 1 meter waterlevel have {avg_m3_per_m} m3 water")
# Out:
# 618836it [01:46, 5825.95it/s]
# every 1 meter waterlevel have 87.85909502482393 m3 water
